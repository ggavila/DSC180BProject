# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("top10average_pageview.csv")

# %%
plt.bar(x=df['article'], height=df['average_view'])
plt.xticks(rotation=90)
plt.xlabel('article')
plt.ylabel('average_view')
plt.savefig('top10pageview.png')
